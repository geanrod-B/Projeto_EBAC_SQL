# %% [markdown]
# # **MÓDULO 24 - Bancos de Dados + SQL**

# %% [markdown]
# Para nossa atividade inicial de SQL trabalharemos com uma base de vendas.
# Abaixo temos o ambiente de preparo para trabalharmos com o SQL lite.

# %%
import sqlite3 #Importando a biblioteca necessária
import pandas as pd

# %%
df_vendas = pd.read_csv("C:/Users/geanr/Desktop/Exercicios/TB_VENDAS.csv", delimiter=';')

# %%
conn = sqlite3.connect(':memory:')
df_vendas.to_sql('tb_vendas', conn, index=False, if_exists='replace')
# Out:
# 24

# %%
def run_query(query):
    return pd.read_sql_query(query, conn)

# %% [markdown]
# # 1) Faça uma consulta que retorne todos os dados da nossa tabela de vendas, com todas linhas e todas colunas.

# %%
query = " select * from tb_vendas"
result_df = run_query(query)
print(result_df)
# Out:
#     ID_COMPRA  ID_CLIENTE   PRODUTO VALOR_UNID  UNIDADES
# 0        1247        9081  CAMISETA       34,5         2
# 1        1248        9081     CALCA       89,9         1
# 2        1250        9560  CAMISETA       34,5         1
# 3        1249        9630   BERMUDA       79,5         2
# 4        1251        9425  CAMISETA       34,5         3
# 5        1252        9425   VESTIDO        102         1
# 6        1253        9481     CALCA       89,9         2
# 7        1254        9785      MEIA       25,9         1
# 8        1255        9786     CALCA       89,9         2
# 9        1256        9787   VESTIDO        102         1
# 10       1257        9788     CALCA       89,9         2
# 11       1258        9789  CAMISETA       34,5         3
# 12       1259        9790  CAMISETA       34,5         1
# 13       1260        9791   BERMUDA       79,5         2
# 14       1261        9792  CAMISETA       34,5         2
# ...

# %% [markdown]
# # 2) Faça uma consulta que retorne apenas 10 linhas da coluna produto.

# %%
query = " select * from tb_vendas limit 10"
result_df = run_query(query)
print(result_df)
# Out:
#    ID_COMPRA  ID_CLIENTE   PRODUTO VALOR_UNID  UNIDADES
# 0       1247        9081  CAMISETA       34,5         2
# 1       1248        9081     CALCA       89,9         1
# 2       1250        9560  CAMISETA       34,5         1
# 3       1249        9630   BERMUDA       79,5         2
# 4       1251        9425  CAMISETA       34,5         3
# 5       1252        9425   VESTIDO        102         1
# 6       1253        9481     CALCA       89,9         2
# 7       1254        9785      MEIA       25,9         1
# 8       1255        9786     CALCA       89,9         2
# 9       1256        9787   VESTIDO        102         1

# %% [markdown]
# # 3) Faça uma consulta que retorne a média do valor por unidade e também das unidades vendidas. Não se esqueça de renomear o nome das colunas ao cria-las.

# %%
query = "select AVG(VALOR_UNID) AS Media_Valor_Unidades from tb_vendas"
result_df = run_query(query)
print(result_df)
# Out:
#    Media_Valor_Unidades
# 0             63.416667

# %%
query = "select AVG(UNIDADES) AS Media_Unidades from tb_vendas"
result_df = run_query(query)
print(result_df)
# Out:
#    Media_Unidades
# 0        1.833333

# %% [markdown]
# # 4) Note que na nossa tabela não temos o total de valor gasto por compra, temos o valor do produto e a quantidade vendida, para termos o valor total precisamos multiplicar essas duas colunas e para multiplicar colunas usamos o *.
# # Faça uma consulta que retorne a coluna ID_COMPRA, ID_CLIENTE e o valor total gasto.
#
# Ex: SELECT TICKET_MEDIO*UNIDADE FROM TB_EXEMPLO

# %%
query = ("select ID_COMPRA, ID_CLIENTE*UNIDADES AS Total_Vendas from tb_vendas")
result_df = run_query(query)
print(result_df)
# Out:
#     ID_COMPRA  Total_Vendas
# 0        1247         18162
# 1        1248          9081
# 2        1250          9560
# 3        1249         19260
# 4        1251         28275
# 5        1252          9425
# 6        1253         18962
# 7        1254          9785
# 8        1255         19572
# 9        1256          9787
# 10       1257         19576
# 11       1258         29367
# 12       1259          9790
# 13       1260         19582
# 14       1261         19584
# 15       1262         19586
# 16       1263          9794
# 17       1264         19590
# 18       1265         39184
# 19       1266          9797
# 20       1267         19596
# 21       1268         29397
# 22       1269         19600
# 23       1270          9801

# %%
query = "select ID_CLIENTE*UNIDADES AS Total_Vendas_ID_CLIENTE from tb_vendas"
result_df = run_query(query)
print(result_df)
# Out:
#     Total_Vendas_ID_CLIENTE
# 0                     18162
# 1                      9081
# 2                      9560
# 3                     19260
# 4                     28275
# 5                      9425
# 6                     18962
# 7                      9785
# 8                     19572
# 9                      9787
# 10                    19576
# 11                    29367
# 12                     9790
# 13                    19582
# 14                    19584
# 15                    19586
# 16                     9794
# 17                    19590
# 18                    39184
# 19                     9797
# 20                    19596
# 21                    29397
# 22                    19600
# 23                     9801

# %%
query = ("select ID_COMPRA*UNIDADES AS Total_Vendas_ID_COMPRAS from tb_vendas")
result_df = run_query(query)
print(result_df)
# Out:
#     Total_Vendas_ID_COMPRAS
# 0                      2494
# 1                      1248
# 2                      1250
# 3                      2498
# 4                      3753
# 5                      1252
# 6                      2506
# 7                      1254
# 8                      2510
# 9                      1256
# 10                     2514
# 11                     3774
# 12                     1259
# 13                     2520
# 14                     2522
# 15                     2524
# 16                     1263
# 17                     2528
# 18                     5060
# 19                     1266
# 20                     2534
# 21                     3804
# 22                     2538
# 23                     1270

# %% [markdown]
# # 5) [DESAFIO] Faça uma consulta que traz a média do valor total gasto que foi calculado no exercício anterior. Note que não queremos a média por pedido e sim a média total, apenas essa informação deve vir na consulta.

# %%
query = " select AVG(UNIDADES*VALOR_UNID) AS Media_valor from tb_vendas"
result_df = run_query(query)
# Exibir o resultado
print(result_df)
# Out:
#    Media_valor
# 0      108.625

# %% [markdown]
# # 6) Diferencie com suas palavras, considerando o repertório que tem criado da área de dados, a utilizadade do SQL e do Python para ciência de dados.

# %% [markdown]
# **A utilidade do Python para Ciência de Dados é muito eficaz e importante, para tratar dados, remover dados ausente(Outliers) e trazer Insights e gráficos facilitando o entendimento para o StakeHolder. Já o SQL é uma ferramenta onde podemos acessar arquivo com bastante dados podendo também visualizar, tratar, calcular e até mesmo fazer algumas alterações semelhantes ao Python. Temos também NoSQL que não utliza estrutura tabular dos bancos de dados relacionais. Sendo mais flexível e adequados para dados não estruturados.**

# %% [markdown]
# # 7) Diferencie com suas palavras banco de dados relacionais de não relacionais.
# Minimo 3 linhas.

# %% [markdown]
# **Banco de dados relacionais organizam os dados com linhas, colunas, tabelas estabelecendo relações entre elas. Eles priorizam organização e consistência dos dados! dados relacionais têm uma estrutura rígida e usam SQL para manipulação de dados, sendo ideais para aplicações que requerem integridade de dados.**
#
# **Banco de dados não relacionais armazenam dados de maneira mais flexível, como documentos, chaves-valor, grafos e colunas e não de dependem de tabelas. Enquanto bancos não relacionais priorizam flexibilidade, escalabilidade e adequados para grandes volumes de dados não estruturados, como redes sociais e Big Data.**

# %% [markdown]
# # 8) Queremos saber da sua opinião, acredita que o SQL pode ser mais prático que o Python para consultas rápidas? Justifique.
# Muitas vezes durante a carreia você terá que escolher qual linguagem utilizar para cada momento afim de entregar o que é solicitado o mais rápido e com qualidade possível, exercite sua argumentação = )

# %% [markdown]
# **Sim, mas em devidas ocasiões. Até onde eu vi e conheço atéo momento, o SQL é mais para consultar, tratar e fazer calculos matemáticos. Porém o PYTHON ele oferce diversas opções de tratamentos, consultas, gráficos e também treinamento em MACHINE Learning. Sendo assim, em ocasiões como busca, consultas e até mesmo calculos mais básicos poriamos utlizar o SQL. Agora para consultas, tratamento e até mesmo treinamento de modelo, seria mais ideal o python, sendo assim, conseguiriamos extrair muito mais dos dados do cliente e trazer resultados mais precisos de acordo com a necessidade do cliente.**
